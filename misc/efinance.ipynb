# %%
import efinance as ef
# 股票代码
stock_code = 'AAPL'
data = ef.stock.get_quote_history(stock_code)
print(data)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:200, in HTTPConnection._new_conn(self)
#     199 try:
# --> 200     sock = connection.create_connection(
#     201         (self._dns_host, self.port),
#     202         self.timeout,
#     203         source_address=self.source_address,
#     204         socket_options=self.socket_options,
#     205     )
#     206 except socket.gaierror as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:604, in HTTPSConnection.connect(self)
#     603 sock: socket.socket | ssl.SSLSocket
# --> 604 self.sock = sock = self._new_conn()
#     605 server_hostname: str = self.host
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:209, in HTTPConnection._new_conn(self)
#     208 except SocketTimeout as e:
# --> 209     raise ConnectTimeoutError(
#     210         self,
#     211         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     212     ) from e
#     214 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x159f8ca50>, 'Connection to push2his.eastmoney.com timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='push2his.eastmoney.com', port=443): Max retries exceeded with url: /api/qt/stock/kline/get?fields1=f1%2Cf2%2Cf3%2Cf4%2Cf5%2Cf6%2Cf7%2Cf8%2Cf9%2Cf10%2Cf11%2Cf12%2Cf13&fields2=f51%2Cf52%2Cf53%2Cf54%2Cf55%2Cf56%2Cf57%2Cf58%2Cf59%2Cf60%2Cf61&beg=19000101&end=20500101&rtntype=6&secid=105.AAPL&klt=101&fqt=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x159f8ca50>, 'Connection to push2his.eastmoney.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[23], line 4
#       2 # 股票代码
#       3 stock_code = 'AAPL'
# ----> 4 data = ef.stock.get_quote_history(stock_code)
#       5 print(data)
#
# File /opt/homebrew/lib/python3.11/site-packages/efinance/stock/getter.py:233, in get_quote_history(stock_codes, beg, end, klt, fqt, **kwargs)
#     150 def get_quote_history(stock_codes: Union[str, List[str]],
#     151                       beg: str = '19000101',
#     152                       end: str = '20500101',
#     153                       klt: int = 101,
#     154                       fqt: int = 1,
#     155                       **kwargs) -> Union[pd.DataFrame, Dict[str, pd.DataFrame]]:
#     156     """
#     157     获取股票的 K 线数据
#     158
#    (...)
#     231
#     232     """
# --> 233     df = get_quote_history_for_stock(
#     234         stock_codes,
#     235         beg=beg,
#     236         end=end,
#     237         klt=klt,
#     238         fqt=fqt,
#     239         **kwargs
#     240
#     241     )
#     242     if isinstance(df, pd.DataFrame):
#     244         df.rename(columns={'代码': '股票代码',
#     245                            '名称': '股票名称'
#     246                            },
#     247                   inplace=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/efinance/common/getter.py:204, in get_quote_history(codes, beg, end, klt, fqt, **kwargs)
#     163 """
#     164 获取股票、ETF、债券的 K 线数据
#     165
#    (...)
#     200
#     201 """
#     203 if isinstance(codes, str):
# --> 204     return get_quote_history_single(codes,
#     205                                     beg=beg,
#     206                                     end=end,
#     207                                     klt=klt,
#     208                                     fqt=fqt,
#     209                                     **kwargs)
#     211 elif hasattr(codes, '__iter__'):
#     212     codes = list(codes)
#
# File /opt/homebrew/lib/python3.11/site-packages/efinance/utils/__init__.py:39, in to_numeric.<locals>.run(*args, **kwargs)
#      37 @wraps(func)
#      38 def run(*args, **kwargs):
# ---> 39     values = func(*args, **kwargs)
#      40     if isinstance(values, pd.DataFrame):
#      41         for column in values.columns:
#
# File /opt/homebrew/lib/python3.11/site-packages/efinance/common/getter.py:99, in get_quote_history_single(code, beg, end, klt, fqt, **kwargs)
#      86 params = (
#      87     ('fields1', 'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13'),
#      88     ('fields2', fields2),
#    (...)
#      94     ('fqt', f'{fqt}'),
#      95 )
#      97 url = 'https://push2his.eastmoney.com/api/qt/stock/kline/get'
# ---> 99 json_response = session.get(
#     100     url, headers=EASTMONEY_REQUEST_HEADERS, params=params).json()
#     101 klines: List[str] = jsonpath(json_response, '$..klines[:]')
#     102 if not klines:
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     504 if isinstance(e.reason, ConnectTimeoutError):
#     505     # TODO: Remove this in 3.0.0: see #2811
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#     510     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='push2his.eastmoney.com', port=443): Max retries exceeded with url: /api/qt/stock/kline/get?fields1=f1%2Cf2%2Cf3%2Cf4%2Cf5%2Cf6%2Cf7%2Cf8%2Cf9%2Cf10%2Cf11%2Cf12%2Cf13&fields2=f51%2Cf52%2Cf53%2Cf54%2Cf55%2Cf56%2Cf57%2Cf58%2Cf59%2Cf60%2Cf61&beg=19000101&end=20500101&rtntype=6&secid=105.AAPL&klt=101&fqt=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x159f8ca50>, 'Connection to push2his.eastmoney.com timed out. (connect timeout=None)'))

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data = ef.stock.get_quote_history('BAC',beg='20060101')
print(data)
# Out:
#       股票名称 股票代码          日期     开盘     收盘     最高     最低       成交量  \
# 0     美国银行  BAC  2007-03-19  40.56  41.13  41.15  40.11  12994400
# 1     美国银行  BAC  2007-03-20  41.13  41.52  41.59  41.07  10062100
# 2     美国银行  BAC  2007-03-21  41.54  42.62  42.76  41.34  21718660
# 3     美国银行  BAC  2007-03-22  42.74  42.40  42.90  42.17  21557600
# 4     美国银行  BAC  2007-03-23  42.46  42.45  42.76  42.17  13102799
# ...    ...  ...         ...    ...    ...    ...    ...       ...
# 4129  美国银行  BAC  2023-08-14  31.05  30.93  31.11  30.75  32563693
# 4130  美国银行  BAC  2023-08-15  30.50  29.94  30.55  29.84  43406068
# 4131  美国银行  BAC  2023-08-16  29.75  29.29  29.84  29.21  47220396
# 4132  美国银行  BAC  2023-08-17  29.44  29.28  29.54  29.11  37202231
# 4133  美国银行  BAC  2023-08-18  29.04  29.11  29.35  28.98  31430361
#
#                成交额    振幅    涨跌幅   涨跌额   换手率
# 0     0.000000e+00  3.14  24.00  7.96  0.29
# 1     0.000000e+00  1.26   0.95  0.39  0.23
# 2     0.000000e+00  3.42   2.65  1.10  0.49
# 3     0.000000e+00  1.71  -0.52 -0.22  0.48
# 4     0.000000e+00  1.39   0.12  0.05  0.29
# ...            ...   ...    ...   ...   ...
# 4129  1.005577e+09  1.15  -1.15 -0.36  0.41
# 4130  1.306131e+09  2.30  -3.20 -0.99  0.55
# 4131  1.390521e+09  2.10  -2.17 -0.65  0.59
# 4132  1.088967e+09  1.47  -0.03 -0.01  0.47
# 4133  9.153613e+08  1.26  -0.58 -0.17  0.40
#
# [4134 rows x 13 columns]

# %%
print(data)
# Out:
#       股票名称 股票代码          日期     开盘     收盘     最高     最低       成交量  \
# 0     美国银行  BAC  2007-03-19  40.56  41.13  41.15  40.11  12994400
# 1     美国银行  BAC  2007-03-20  41.13  41.52  41.59  41.07  10062100
# 2     美国银行  BAC  2007-03-21  41.54  42.62  42.76  41.34  21718660
# 3     美国银行  BAC  2007-03-22  42.74  42.40  42.90  42.17  21557600
# 4     美国银行  BAC  2007-03-23  42.46  42.45  42.76  42.17  13102799
# ...    ...  ...         ...    ...    ...    ...    ...       ...
# 4129  美国银行  BAC  2023-08-14  31.05  30.93  31.11  30.75  32563693
# 4130  美国银行  BAC  2023-08-15  30.50  29.94  30.55  29.84  43406068
# 4131  美国银行  BAC  2023-08-16  29.75  29.29  29.84  29.21  47220396
# 4132  美国银行  BAC  2023-08-17  29.44  29.28  29.54  29.11  37202231
# 4133  美国银行  BAC  2023-08-18  29.04  29.11  29.35  28.98  31430361
#
#                成交额    振幅    涨跌幅   涨跌额   换手率
# 0     0.000000e+00  3.14  24.00  7.96  0.29
# 1     0.000000e+00  1.26   0.95  0.39  0.23
# 2     0.000000e+00  3.42   2.65  1.10  0.49
# 3     0.000000e+00  1.71  -0.52 -0.22  0.48
# 4     0.000000e+00  1.39   0.12  0.05  0.29
# ...            ...   ...    ...   ...   ...
# 4129  1.005577e+09  1.15  -1.15 -0.36  0.41
# 4130  1.306131e+09  2.30  -3.20 -0.99  0.55
# 4131  1.390521e+09  2.10  -2.17 -0.65  0.59
# 4132  1.088967e+09  1.47  -0.03 -0.01  0.47
# 4133  9.153613e+08  1.26  -0.58 -0.17  0.40
#
# [4134 rows x 13 columns]

# %%
print(data)
# Out:
#       股票名称 股票代码          日期     开盘     收盘     最高     最低       成交量  \
# 0     美国银行  BAC  2007-03-19  40.56  41.13  41.15  40.11  12994400
# 1     美国银行  BAC  2007-03-20  41.13  41.52  41.59  41.07  10062100
# 2     美国银行  BAC  2007-03-21  41.54  42.62  42.76  41.34  21718660
# 3     美国银行  BAC  2007-03-22  42.74  42.40  42.90  42.17  21557600
# 4     美国银行  BAC  2007-03-23  42.46  42.45  42.76  42.17  13102799
# ...    ...  ...         ...    ...    ...    ...    ...       ...
# 4129  美国银行  BAC  2023-08-14  31.05  30.93  31.11  30.75  32563693
# 4130  美国银行  BAC  2023-08-15  30.50  29.94  30.55  29.84  43406068
# 4131  美国银行  BAC  2023-08-16  29.75  29.29  29.84  29.21  47220396
# 4132  美国银行  BAC  2023-08-17  29.44  29.28  29.54  29.11  37202231
# 4133  美国银行  BAC  2023-08-18  29.04  29.11  29.35  28.98  31430361
#
#                成交额    振幅    涨跌幅   涨跌额   换手率
# 0     0.000000e+00  3.14  24.00  7.96  0.29
# 1     0.000000e+00  1.26   0.95  0.39  0.23
# 2     0.000000e+00  3.42   2.65  1.10  0.49
# 3     0.000000e+00  1.71  -0.52 -0.22  0.48
# 4     0.000000e+00  1.39   0.12  0.05  0.29
# ...            ...   ...    ...   ...   ...
# 4129  1.005577e+09  1.15  -1.15 -0.36  0.41
# 4130  1.306131e+09  2.30  -3.20 -0.99  0.55
# 4131  1.390521e+09  2.10  -2.17 -0.65  0.59
# 4132  1.088967e+09  1.47  -0.03 -0.01  0.47
# 4133  9.153613e+08  1.26  -0.58 -0.17  0.40
#
# [4134 rows x 13 columns]

# %%
print(data)
# Out:
#       股票名称 股票代码          日期     开盘     收盘     最高     最低       成交量  \
# 0     美国银行  BAC  2007-03-19  40.56  41.13  41.15  40.11  12994400
# 1     美国银行  BAC  2007-03-20  41.13  41.52  41.59  41.07  10062100
# 2     美国银行  BAC  2007-03-21  41.54  42.62  42.76  41.34  21718660
# 3     美国银行  BAC  2007-03-22  42.74  42.40  42.90  42.17  21557600
# 4     美国银行  BAC  2007-03-23  42.46  42.45  42.76  42.17  13102799
# ...    ...  ...         ...    ...    ...    ...    ...       ...
# 4129  美国银行  BAC  2023-08-14  31.05  30.93  31.11  30.75  32563693
# 4130  美国银行  BAC  2023-08-15  30.50  29.94  30.55  29.84  43406068
# 4131  美国银行  BAC  2023-08-16  29.75  29.29  29.84  29.21  47220396
# 4132  美国银行  BAC  2023-08-17  29.44  29.28  29.54  29.11  37202231
# 4133  美国银行  BAC  2023-08-18  29.04  29.11  29.35  28.98  31430361
#
#                成交额    振幅    涨跌幅   涨跌额   换手率
# 0     0.000000e+00  3.14  24.00  7.96  0.29
# 1     0.000000e+00  1.26   0.95  0.39  0.23
# 2     0.000000e+00  3.42   2.65  1.10  0.49
# 3     0.000000e+00  1.71  -0.52 -0.22  0.48
# 4     0.000000e+00  1.39   0.12  0.05  0.29
# ...            ...   ...    ...   ...   ...
# 4129  1.005577e+09  1.15  -1.15 -0.36  0.41
# 4130  1.306131e+09  2.30  -3.20 -0.99  0.55
# 4131  1.390521e+09  2.10  -2.17 -0.65  0.59
# 4132  1.088967e+09  1.47  -0.03 -0.01  0.47
# 4133  9.153613e+08  1.26  -0.58 -0.17  0.40
#
# [4134 rows x 13 columns]

# %%
import efinance as ef

# %%
ef.stock.get_realtime_quotes()
# Out:
#         股票代码  股票名称     涨跌幅    最新价     最高     最低     今开    涨跌额    换手率     量比  \
# 0     301533   N威马  155.93   75.5   85.8   61.5   66.0   46.0  81.60      -
# 1     688693  N锴威特   109.4   85.5  96.99  75.02   80.0  44.67  86.57      -
# 2     688573  C信宇人   37.17   57.2  67.66  46.18  46.18   15.5  87.98   0.98
# 3     688285  高铁电气   20.02  10.37  10.37   8.79   8.79   1.73  33.69  19.62
# 4     301203  国泰环保   20.01  47.86  47.86  39.27   39.9   7.98  58.41   4.55
# ...      ...   ...     ...    ...    ...    ...    ...    ...    ...    ...
# 5497  301289  国缆检测  -10.72   59.3  66.58  58.62  65.73  -7.12  26.64   0.92
# 5498  301017  漱玉平民  -11.18  19.47   21.5  19.47   21.5  -2.45  11.00   1.11
# 5499  301408  华人健康  -11.58  21.61  23.39   21.4  23.18  -2.83  52.43   1.03
# 5500  301235  华康医疗  -12.38   24.2  27.66  24.01  27.51  -3.42  17.68   1.29
# 5501  831906  舜宇精工  -13.54  11.43  11.96  11.41   11.9  -1.79   8.23   5.27
#
#         动态市盈率     成交量            成交额   昨日收盘         总市值        流通市值      行情ID  \
# 0      102.61  176552  1255759428.24   29.5  7422155850  1633592217  0.301533
# 1      107.44  142380   1186963009.0  40.83  6300000041  1406123424  1.688693
# 2    -1506.56  171752    937980786.0   41.7  5591550994  1116676761  1.688573
# 3       69.67  301200    301320906.0   8.64  3902126398   927026150  1.688285
# 4       31.02   99689    458379856.5  39.88  3828800000   816859835  0.301203
# ...       ...     ...            ...    ...         ...         ...       ...
# 5497    76.28   67526   422674606.62  66.42  4625400000  1503249129  0.301289
# 5498    30.56  120199   240400902.18  21.92  7891973811  2128075011  0.301017
# 5499     73.3  295398   651323117.84  24.44  8644216100  1217638962  0.301408
# 5500   -36.91   88280   225721700.07  27.62  2555520000  1208504440  0.301235
# 5501    15.37   15113    17697348.05  13.22   742607100   209905092  0.831906
#
#      市场类型                 更新时间       最新交易日
# 0      深A  2023-08-18 15:34:57  2023-08-18
# 1      沪A  2023-08-18 15:59:57  2023-08-18
# 2      沪A  2023-08-18 16:00:01  2023-08-18
# 3      沪A  2023-08-18 15:59:33  2023-08-18
# 4      深A  2023-08-18 15:34:42  2023-08-18
# ...   ...                  ...         ...
# 5497   深A  2023-08-18 15:34:45  2023-08-18
# 5498   深A  2023-08-18 15:34:15  2023-08-18
# 5499   深A  2023-08-18 15:34:27  2023-08-18
# 5500   深A  2023-08-18 15:34:15  2023-08-18
# 5501   深A  2023-08-18 15:36:07  2023-08-18
#
# [5502 rows x 20 columns]

# %%
from efinance.utils import search_quote
search_quote(keyword='DJI',count=10)
# Out:
# [Quote(code='DJIA', name='Global X Dow 30 Covered Call ET', pinyin='GLOBALXDOW30COVEREDCALLET', id='DJIA7', jys='AMEX', classify='UsStock', market_type='7', security_typeName='美股', security_type='7', mkt_num='107', type_us='5', quote_id='107.DJIA', unified_code='DJIA', inner_code='13868919752883'),
#  Quote(code='DJIA', name='道琼斯', pinyin='DQS', id='DJIA_UI', jys='QQZS', classify='UniversalIndex', market_type='_UI', security_typeName='指数', security_type='11', mkt_num='100', type_us='0', quote_id='100.DJIA', unified_code='DJIA', inner_code='20933916664720'),
#  Quote(code='DOGG', name='FT Cboe Vest DJIA Dogs 10 Targe', pinyin='FTCBOEVESTDJIADOGS10TARGE', id='DOGG7', jys='AMEX', classify='UsStock', market_type='7', security_typeName='美股', security_type='7', mkt_num='107', type_us='5', quote_id='107.DOGG', unified_code='DOGG', inner_code='48969702947325'),
#  Quote(code='NDJI', name='Nationwide Dow Jones Risk-Manag', pinyin='NATIONWIDEDOWJONESRISKMANAG', id='NDJI7', jys='AMEX', classify='UsStock', market_type='7', security_typeName='美股', security_type='7', mkt_num='107', type_us='5', quote_id='107.NDJI', unified_code='NDJI', inner_code='44826000527811'),
#  Quote(code='0OO5', name='ELEKTROMETAL AD-PAZARDJIK ORD S', pinyin='ELEKTROMETALADPAZARDJIKORDS', id='0OO5_UKS', jys='LSE', classify='LSE', market_type='_UKS', security_typeName='英股', security_type='24', mkt_num='155', type_us='1', quote_id='155.0OO5', unified_code='0OO5', inner_code='15748546078427'),
#  Quote(code='47BH', name='HSBC BANK PLC WRT LKD JIANGU TR', pinyin='HSBCBANKPLCWRTLKDJIANGUTR', id='47BH_UKS', jys='LSE', classify='LSE', market_type='_UKS', security_typeName='债券', security_type='16', mkt_num='155', type_us='4', quote_id='155.47BH', unified_code='47BH', inner_code='20063626059131'),
#  Quote(code='74CQ', name='HSBC BANK PLC WNTS LKD ORD JIND', pinyin='HSBCBANKPLCWNTSLKDORDJIND', id='74CQ_UKS', jys='LSE', classify='LSE', market_type='_UKS', security_typeName='债券', security_type='16', mkt_num='155', type_us='4', quote_id='155.74CQ', unified_code='74CQ', inner_code='22620347640411'),
#  Quote(code='IGDA', name='INVESCO MARKETS II PLC IVZ DJ I', pinyin='INVESCOMARKETSIIPLCIVZDJI', id='IGDA_UKS', jys='LSE', classify='LSE', market_type='_UKS', security_typeName='英股', security_type='24', mkt_num='155', type_us='3', quote_id='155.IGDA', unified_code='IGDA', inner_code='29251133247941')]

# %%
from efinance.common import get_latest_quote
ef.common.get_quote_history('100.DJIA')
# Out:
# 证券代码 "100.DJIA" 可能有误
# Empty DataFrame
# Columns: [名称, 代码, 日期, 开盘, 收盘, 最高, 最低, 成交量, 成交额, 振幅, 涨跌幅, 涨跌额, 换手率]
# Index: []

# %%
ef.stock.get_members('000300')
# Out:
#        指数代码   指数名称    股票代码  股票名称  股票权重
# 0    000300  沪深300  600519  贵州茅台  6.09
# 1    000300  沪深300  300750  宁德时代  3.29
# 2    000300  沪深300  601318  中国平安  2.75
# 3    000300  沪深300  600036  招商银行  2.09
# 4    000300  沪深300  000858   五粮液  1.73
# ..      ...    ...     ...   ...   ...
# 295  000300  沪深300  601698  中国卫通  0.04
# 296  000300  沪深300  000800  一汽解放  0.04
# 297  000300  沪深300  300979  华利集团  0.04
# 298  000300  沪深300  601236  红塔证券  0.04
# 299  000300  沪深300  001289  龙源电力  0.02
#
# [300 rows x 5 columns]

# %%
import efinance as ef

# %%
ef.stock.get_members('000300')
# Out:
#        指数代码   指数名称    股票代码  股票名称  股票权重
# 0    000300  沪深300  600519  贵州茅台  6.09
# 1    000300  沪深300  300750  宁德时代  3.29
# 2    000300  沪深300  601318  中国平安  2.75
# 3    000300  沪深300  600036  招商银行  2.09
# 4    000300  沪深300  000858   五粮液  1.73
# ..      ...    ...     ...   ...   ...
# 295  000300  沪深300  601698  中国卫通  0.04
# 296  000300  沪深300  000800  一汽解放  0.04
# 297  000300  沪深300  300979  华利集团  0.04
# 298  000300  沪深300  601236  红塔证券  0.04
# 299  000300  沪深300  001289  龙源电力  0.02
#
# [300 rows x 5 columns]

# %%
data300 = ef.stock.get_members('000300')

# %%
data300.to_csv('list300')

# %%
import investpy

df = investpy.get_stock_historical_data(stock='AAPL',
                                        country='United States',
                                        from_date='01/01/2010',
                                        to_date='01/01/2020')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 import investpy
# ----> 3 df = investpy.get_stock_historical_data(stock='AAPL',
#       4                                         country='United States',
#       5                                         from_date='01/01/2010',
#       6                                         to_date='01/01/2020')
#       7 print(df.head())
#
# File /opt/homebrew/lib/python3.11/site-packages/investpy/stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
ef.stock.get_members('000300')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ef.stock.get_members('000300')
#
# NameError: name 'ef' is not defined
